# %% [markdown]
# # Machine Learning
# ## Compulsory task

# %% [markdown]
# 1. For each of the following examples describe at least one possible input and
# output. Justify your answers:
# * 1.1 A self-driving car
# * 1.2 Netflix recommendation system
# * 1.3 Signature recognition
# * 1.4 Medical diagnosis

# %% [markdown]
# 1. Answer here
#
# |      | Input(s)          | Output                             |
# | ---- | ----------------- | ---------------------------------  |
# | 1.1  | Photos of objects | Identifying what the photos are of |
# This would enable autonomous cars to be able to detect what objects they see around them.
# This could be useful from identifying which objects could pose potential hazards,
# to simply being able to understand roadsigns.
#
# | 1.2  | Shows that the user has watched | Shows that the user may be interested in |
# This would allow Netlix to find shows similar to ones that the user has already watched, which would increase the likelihood of the user engaging with them.
#
# | 1.3  | Signature examples | Does the signature match? |
# This could be used to detect fraudulent activity. If a machine can correctly identify when a signature has been produced by the correct individual, it would prevent bad actors from forging copies
#
# | 1.4  | Symptoms | Potential medical conditions |
# If certain combinations of symptoms can be linked to different ailments, it would allow for quicker and more accurat diagnostic of a patient's condition(s).

# %% [markdown]
# 2. For each of the following case studies, determine whether it is appropriate to utilise regression or classification machine learning algorithms. Justify your answers:
# * 2.1 Classifying emails as promotion or social based on their content and metadata.
# * 2.2 Forecasting the stock price of a company based on historical data and market trends.
# * 2.3 Sorting images of animals into different species based on their visual features.
# * 2.4 Predicting the likelihood of a patient having a particular disease based on medical history and diagnostic test results.

# %% [markdown]
# 2. Answer here
# * 2.1 - Classification. This is because we want the algorithm to sort emails into specific categories based on their content
#
# * 2.2 - Regression. This example requires prediction of variables (stock prices) based on input features (historical data and market trends)
#
# * 2.3 - Classification. Again, we want the algorithm to sort images into pre-defined categories
#
# * 2.4 - Regression. This one is a bit trickier, but I believe regression would best suit this example as we are trying to predict an output (likelihood of disease) based on input features (medical history and diagnostic results)

# %% [markdown]
# 3. For each of the following real-world problems, determine whether it is appropriate to utilise a supervised or unsupervised machine learning algorithm. Justify your answers:
# * 3.1 Detecting anomalies in a manufacturing process using sensor data without prior knowledge of specific anomaly patterns.
# * 3.2 Predicting customer lifetime value based on historical transaction data and customer demographics.
# * 3.3 Segmenting customer demographics based on their purchase history, browsing behaviour, and preferences.
# * 3.4 Analysing social media posts to categorise them into different themes.

# %% [markdown]
# 3. Answer here
# * 3.1 - Unsupervised. Withour prior knowledge of specific patterns, the algorithm must discover these on its own in order to separate the potential classes
#
# * 3.2 - Supervised. The algorithm can first find patterns in previous customer data, and use this to predict future customer value.
#
# * 3.3 - Supervised. Again, previous customer data can be utilised to classify which demographic a customer falls into. This can be useful for targeted adverts, for example.
#
# * 3.4 - Unsupervised. With data such as social media posts, it would be difficult to feed an algorithm gold standard data as there is not necessarily a "correct" answer. It would be better to allow the program to find groups on its own.

# %% [markdown]
# 4.
# For each of the following real-world problems, determine whether it is appropriate to utilise semi-supervised machine learning algorithms. Justify your answers:
# * 4.1 Predicting fraudulent financial transactions using a dataset where most transactions are labelled as fraudulent or legitimate.
# * 4.2 Analysing customer satisfaction surveys where only a small portion of the data is labelled with satisfaction ratings.
# *4.3 Identifying spam emails in a dataset where the majority of emails are labelled.
# * 4.4 Predicting the probability of default for credit card applicants based on their complete financial and credit-related information.

# %% [markdown]
# 4. Answer here
# * 4.1 No - as most transactions are labelled, this would be better suited for a supervised learning algorithm
# * 4.2 Yes - as not much of the data is fully labelled, it would not be suited for fully supervised learning
# * 4.3 No - again, as the majoirty of emails are labelled, fully supervised learning would be more beneficial
# * 4.4 No - as all relevant information is available, fully supervised learning would work better
